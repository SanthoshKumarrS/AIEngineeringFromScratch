# %%
from datasets import load_dataset

# %%
import datasets
import huggingface_hub

print(datasets.__version__)
print(huggingface_hub.__version__)
# Out:
# 5.0.0
# 1.22.0

# %%
from datasets.utils.logging import set_verbosity_info

set_verbosity_info()

from datasets import load_dataset

dataset = load_dataset(
    "stanfordnlp/imdb",
    split="train[:5]"
)

print(dataset)
# Out:
# Generating dataset imdb (/home/santhosh/.cache/huggingface/datasets/stanfordnlp___imdb/plain_text/0.0.0/e6281661ce1c48d982bc483cf8a173c1bbeb5d31)
# Downloading and preparing dataset imdb/plain_text to /home/santhosh/.cache/huggingface/datasets/stanfordnlp___imdb/plain_text/0.0.0/e6281661ce1c48d982bc483cf8a173c1bbeb5d31...
# plain_text/unsupervised-00000-of-00001.p(…):   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 7
#       3 set_verbosity_info()
#       4
#       5 from datasets import load_dataset
#       6
# ----> 7 dataset = load_dataset(
#       8     "stanfordnlp/imdb",
#       9     split="train[:5]"
#      10 )
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/datasets/load.py:1718, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1715     return builder_instance.as_streaming_dataset(split=split)
#    1717 # Download and prepare data
# -> 1718 builder_instance.download_and_prepare(
#    1719     download_config=download_config,
#    1720     download_mode=download_mode,
#    1721     verification_mode=verification_mode,
#    1722     num_proc=num_proc,
#    1723     storage_options=storage_options,
#    1724 )
#    1726 # Build dataset for splits
#    1727 keep_in_memory = (
#    1728     keep_in_memory if keep_in_memory is not None else is_small_dataset(builder_instance.info.dataset_size)
#    1729 )
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/datasets/builder.py:890, in DatasetBuilder.download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, dl_manager, base_path, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#     888 if num_proc is not None:
#     889     prepare_split_kwargs["num_proc"] = num_proc
# --> 890 self._download_and_prepare(
#     891     dl_manager=dl_manager,
#     892     verification_mode=verification_mode,
#     893     **prepare_split_kwargs,
#     894     **download_and_prepare_kwargs,
#     895 )
#     896 # Sync info
#     897 self.info.dataset_size = sum(split.num_bytes for split in self.info.splits.values())
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/datasets/builder.py:929, in DatasetBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_split_kwargs)
#     927 split_dict = SplitDict(dataset_name=self.dataset_name)
#     928 split_generators_kwargs = self._make_split_generators_kwargs(prepare_split_kwargs)
# --> 929 split_generators: list[SplitGenerator] = self._split_generators(dl_manager, **split_generators_kwargs)
#     931 # Checksums verification
#     932 if verification_mode == VerificationMode.ALL_CHECKS and dl_manager.record_checksums:
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/datasets/packaged_modules/parquet/parquet.py:119, in Parquet._split_generators(self, dl_manager)
#     117     raise ValueError(f"At least one data file must be specified, but got data_files={self.config.data_files}")
#     118 dl_manager.download_config.extract_on_the_fly = True
# --> 119 data_files = dl_manager.download(self.config.data_files)
#     120 splits = []
#     121 for split_name, files in data_files.items():
#     122     # Infer features if they are stored in the arrow schema
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/datasets/download/download_manager.py:159, in DownloadManager.download(self, url_or_urls)
#     157 start_time = datetime.now()
#     158 with stack_multiprocessing_download_progress_bars():
# --> 159     downloaded_path_or_paths = map_nested(
#     160         download_func,
#     161         url_or_urls,
#     162         map_tuple=True,
#     163         num_proc=download_config.num_proc,
#     164         desc="Downloading data files",
#     165         batched=True,
#     166         batch_size=-1,
#     167     )
#     168 duration = datetime.now() - start_time
#     169 logger.info(f"Downloading took {duration.total_seconds() // 60} min")
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/datasets/utils/py_utils.py:520, in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, parallel_min_length, batched, batch_size, types, disable_tqdm, desc)
#     517         batch_size = max(len(iterable) // num_proc + int(len(iterable) % num_proc > 0), 1)
#     518     iterable = list(iter_batched(iterable, batch_size))
#     519 mapped = [
# --> 520     _single_map_nested((function, obj, batched, batch_size, types, None, True, None))
#     521     for obj in hf_tqdm(iterable, disable=disable_tqdm, desc=desc)
#     522 ]
#     523 if batched:
#     524     mapped = [mapped_item for mapped_batch in mapped for mapped_item in mapped_batch]
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/datasets/utils/py_utils.py:407, in _single_map_nested(args)
#     403     return {
#     404         k: _single_map_nested((function, v, batched, batch_size, types, None, True, None)) for k, v in pbar
#     405     }
#     406 else:
# --> 407     mapped = [_single_map_nested((function, v, batched, batch_size, types, None, True, None)) for v in pbar]
#     408     if isinstance(data_struct, list):
#     409         return mapped
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/datasets/utils/py_utils.py:388, in _single_map_nested(args)
#     381         return function(data_struct)
#     382 if (
#     383     batched
#     384     and not isinstance(data_struct, dict)
#     385     and isinstance(data_struct, types)
#     386     and all(not isinstance(v, (dict, types)) for v in data_struct)
#     387 ):
# --> 388     return [mapped_item for batch in iter_batched(data_struct, batch_size) for mapped_item in function(batch)]
#     390 # Reduce logging to keep things readable in multiprocessing with tqdm
#     391 if rank is not None and logging.get_verbosity() < logging.WARNING:
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/datasets/download/download_manager.py:220, in DownloadManager._download_batched(self, url_or_filenames, download_config)
#     206     return thread_map(
#     207         download_func,
#     208         url_or_filenames,
#    (...)    216         tqdm_class=tqdm,
#     217     )
#     218 else:
#     219     return [
# --> 220         self._download_single(url_or_filename, download_config=download_config)
#     221         for url_or_filename in url_or_filenames
#     222     ]
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/datasets/download/download_manager.py:229, in DownloadManager._download_single(self, url_or_filename, download_config)
#     226 if is_relative_path(url_or_filename):
#     227     # append the relative path to the base_path
#     228     url_or_filename = url_or_path_join(self._base_path, url_or_filename)
# --> 229 out = cached_path(url_or_filename, download_config=download_config)
#     230 out = tracked_str(out)
#     231 out.set_origin(url_or_filename)
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/datasets/utils/file_utils.py:188, in cached_path(url_or_filename, download_config, **download_kwargs)
#     178 resolved_path = huggingface_hub.HfFileSystem(
#     179     endpoint=config.HF_ENDPOINT, token=download_config.token
#     180 ).resolve_path(url_or_filename)
#     181 try:
#     182     output_path = huggingface_hub.HfApi(
#     183         endpoint=config.HF_ENDPOINT,
#     184         token=download_config.token,
#     185         library_name="datasets",
#     186         library_version=__version__,
#     187         user_agent=get_datasets_user_agent(download_config.user_agent),
# --> 188     ).hf_hub_download(
#     189         repo_id=resolved_path.repo_id,
#     190         repo_type=resolved_path.repo_type,
#     191         revision=resolved_path.revision,
#     192         filename=resolved_path.path_in_repo,
#     193         force_download=download_config.force_download,
#     194         proxies=download_config.proxies,
#     195     )
#     196 except (
#     197     huggingface_hub.utils.RepositoryNotFoundError,
#     198     huggingface_hub.utils.EntryNotFoundError,
#     199     huggingface_hub.utils.RevisionNotFoundError,
#     200     huggingface_hub.utils.GatedRepoError,
#     201 ) as e:
#     202     raise FileNotFoundError(str(e)) from e
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/huggingface_hub/hf_api.py:6442, in HfApi.hf_hub_download(self, repo_id, filename, subfolder, repo_type, revision, cache_dir, local_dir, force_download, etag_timeout, token, local_files_only, tqdm_class, dry_run)
#    6438         if token is None:
#    6439             # Cannot do `token = token or self.token` as token can be `False`.
#    6440             token = self.token
#    6441
# -> 6442         return hf_hub_download(
#    6443             repo_id=repo_id,
#    6444             filename=filename,
#    6445             subfolder=subfolder,
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1018, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     997     return _hf_hub_download_to_local_dir(
#     998         # Destination
#     999         local_dir=local_dir,
#    (...)   1015         dry_run=dry_run,
#    1016     )
#    1017 else:
# -> 1018     return _hf_hub_download_to_cache_dir(
#    1019         # Destination
#    1020         cache_dir=cache_dir,
#    1021         # File info
#    1022         repo_id=repo_id,
#    1023         filename=filename,
#    1024         repo_type=repo_type,
#    1025         revision=revision,
#    1026         # HTTP info
#    1027         endpoint=endpoint,
#    1028         etag_timeout=etag_timeout,
#    1029         headers=hf_headers,
#    1030         token=token,
#    1031         # Additional options
#    1032         local_files_only=local_files_only,
#    1033         force_download=force_download,
#    1034         tqdm_class=tqdm_class,
#    1035         dry_run=dry_run,
#    1036     )
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1241, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1238 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1240 with WeakFileLock(lock_path):
# -> 1241     _download_to_tmp_and_move(
#    1242         incomplete_path=Path(blob_path + ".incomplete"),
#    1243         destination_path=Path(blob_path),
#    1244         url_to_download=url_to_download,
#    1245         headers=headers,
#    1246         expected_size=expected_size,
#    1247         filename=filename,
#    1248         force_download=force_download,
#    1249         etag=etag,
#    1250         xet_file_data=xet_file_data,
#    1251         tqdm_class=tqdm_class,
#    1252     )
#    1253     if not os.path.exists(pointer_path):
#    1254         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1925, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, headers, expected_size, filename, force_download, etag, xet_file_data, tqdm_class)
#    1923 if xet_file_data is not None and is_xet_available():
#    1924     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1925     xet_get(
#    1926         incomplete_path=tmp_path,
#    1927         xet_file_data=xet_file_data,
#    1928         headers=headers,
#    1929         expected_size=expected_size,
#    1930         displayed_filename=filename,
#    1931         tqdm_class=tqdm_class,
#    1932     )
#    1933 else:
#    1934     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File ~/Projects/AIEngineeringFromScratch/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:568, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     565     _prev = current
#     567 try:
# --> 568     with session.new_file_download_group(
#     569         token_refresh_url=xet_file_data.refresh_route,
#     570         token_refresh_headers=headers,
#     571         custom_headers=xet_headers,
#     572         progress_callback=_on_progress,
#     573     ) as group:
#     574         group.start_download_file(
#     575             XetFileInfo(xet_file_data.file_hash, expected_size), str(incomplete_path.absolute())
#     576         )
#     577 except KeyboardInterrupt:
#
# KeyboardInterrupt:

# %%
#Downloading a Small Model from the Hub

from huggingface_hub import hf_hub_download, snapshot_download

model_path = hf_hub_download(
    repo_id="sentence-transformers/all-MiniLM-L6-v2",
    filename="config.json"
)
print(f"Cached at: {model_path}")

model_dir = snapshot_download("sentence-transformers/all-MiniLM-L6-v2")
print(f"Full model at: {model_dir}")
# Out:
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Cached at: /home/santhosh/.cache/huggingface/hub/models--sentence-transformers--all-MiniLM-L6-v2/snapshots/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config.json
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 30 files:   0%|          | 0/30 [00:00<?, ?it/s]
# Full model at: /home/santhosh/.cache/huggingface/hub/models--sentence-transformers--all-MiniLM-L6-v2/snapshots/1110a243fdf4706b3f48f1d95db1a4f5529b4d41
